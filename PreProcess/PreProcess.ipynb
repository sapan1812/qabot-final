# %%
# text cleaning
contractions = {
    "ain't": "are not",
    "aren't": "are not",
    "can't": "cannot",
    "can't've": "cannot have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he had",
    "he'd've": "he would have",
    "he'll": "he shall",
    "he'll've": "he shall have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how has",
    "i'd": "I would",
    "i'd've": "I would have",
    "i'll": "I will",
    "i'll've": "I will have",
    "i'm": "I am",
    "i've": "I have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": " she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she has / she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so is",
    "that'd": "that had",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what shall",
    "what'll've": "what shall have",
    "what're": "what are",
    "what's": "what has",
    "what've": "what have",
    "when's": "when has",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where ha",
    "where've": "where have",
    "who'll": "who shall",
    "who'll've": "who shall have",
    "who's": "who has",
    "who've": "who have",
    "why's": "why has",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you had",
    "you'd've": "you would have",
    "you'll": "you shall",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have"
    }

puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£', 
         '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', 
         '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', 
         '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', 
         '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√']

EMOTICONS = {
        u":‑\)":"Happy face or smiley",
        u":\)":"Happy face or smiley",
        u":-\]":"Happy face or smiley",
        u":\]":"Happy face or smiley",
        u":-3":"Happy face smiley",
        u":3":"Happy face smiley",
        u":->":"Happy face smiley",
        u":>":"Happy face smiley"
    }

chat_words_str = """AFAIK=As Far As I Know
        AFK=Away From Keyboard
        ASAP=As Soon As Possible
        ATK=At The Keyboard
        ATM=At The Moment
        A3=Anytime, Anywhere, Anyplace
        BAK=Back At Keyboard
        BBL=Be Back Later
        BBS=Be Back Soon
        BFN=Bye For Now
        B4N=Bye For Now
        BRB=Be Right Back
        BRT=Be Right There
        BTW=By The Way
        B4=Before
        B4N=Bye For Now
        CU=See You
        CUL8R=See You Later
        CYA=See You
        FAQ=Frequently Asked Questions
        FC=Fingers Crossed
        FWIW=For What It's Worth
        FYI=For Your Information
        GAL=Get A Life
        GG=Good Game
        GN=Good Night
        GMTA=Great Minds Think Alike
        7K=Sick:-D Laugher"""

EMO_UNICODE = {
        u':1st_place_medal:': u'\U0001F947',
        u':2nd_place_medal:': u'\U0001F948',
        u':3rd_place_medal:': u'\U0001F949',
        u':AB_button_(blood_type):': u'\U0001F18E',
        u':ATM_sign:': u'\U0001F3E7',
        u':A_button_(blood_type):': u'\U0001F170',
        u':Afghanistan:': u'\U0001F1E6 \U0001F1EB',
        u':Albania:': u'\U0001F1E6 \U0001F1F1'
    } 

UNICODE_EMO = {v: k for k, v in EMO_UNICODE.items()}

chat_words_str = """AFAIK=As Far As I Know
            AFK=Away From Keyboard
            ASAP=As Soon As Possible
            ATK=At The Keyboard
            ATM=At The Moment
            A3=Anytime, Anywhere, Anyplace
            BAK=Back At Keyboard
            BBL=Be Back Later
            BBS=Be Back Soon
            BFN=Bye For Now
            B4N=Bye For Now
            BRB=Be Right Back
            BRT=Be Right There
            BTW=By The Way
            B4=Before
            B4N=Bye For Now
            CU=See You
            CUL8R=See You Later
            CYA=See You
            FAQ=Frequently Asked Questions
            FC=Fingers Crossed
            FWIW=For What It's Worth
            FYI=For Your Information
            GAL=Get A Life
            GG=Good Game
            GN=Good Night
            GMTA=Great Minds Think Alike
            GR8=Great!
            G9=Genius
            IC=I See
            ICQ=I Seek you (also a chat program)
            ILU=ILU: I Love You
            IMHO=In My Honest/Humble Opinion
            IMO=In My Opinion
            IOW=In Other Words
            IRL=In Real Life
            KISS=Keep It Simple, Stupid
            LDR=Long Distance Relationship
            LMAO=Laugh My A.. Off
            LOL=Laughing Out Loud
            LTNS=Long Time No See
            L8R=Later
            MTE=My Thoughts Exactly
            M8=Mate
            NRN=No Reply Necessary
            OIC=Oh I See
            PITA=Pain In The A..
            PRT=Party
            PRW=Parents Are Watching
            ROFL=Rolling On The Floor Laughing
            ROFLOL=Rolling On The Floor Laughing Out Loud
            ROTFLMAO=Rolling On The Floor Laughing My A.. Off
            SK8=Skate
            STATS=Your sex and age
            ASL=Age, Sex, Location
            THX=Thank You
            TTFN=Ta-Ta For Now!
            TTYL=Talk To You Later
            U=You
            U2=You Too
            U4E=Yours For Ever
            WB=Welcome Back
            WTF=What The F...
            WTG=Way To Go!
            WUF=Where Are You From?
            W8=Wait...
            7K=Sick:-D Laugher"""

# %%
import warnings

warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import math
import re
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
import spacy
from spellchecker import SpellChecker
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
from gensim import models
from gensim.models import word2vec
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score
from wordcloud import WordCloud

# %%
tags = pd.read_csv('Dataset/Tags.csv', sep=',')
tags.head()
# Out:
#    Id             Tag
# 0  80            flex
# 1  80  actionscript-3
# 2  80             air
# 3  90             svn
# 4  90     tortoisesvn

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3750994 entries, 0 to 3750993
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Tag     object
# dtypes: int64(1), object(1)
# memory usage: 57.2+ MB

# %%
tags.isna().sum()
# Out:
# Id        0
# Tag    1113
# dtype: int64

# %%
tags.fillna('NA', inplace=True)

# %%
tags['Tag'] = tags['Tag'].str.lower()

# %%
tags[tags.Tag == 'python'].shape
# Out:
# (64601, 2)

# %%
python_tags_df = tags[tags.Tag == 'python']
python_tags_df.sort_values(by='Id')
python_tags_df.head()
# Out:
#          Id     Tag
# 312   11060  python
# 503   17250  python
# 546   19030  python
# 905   31340  python
# 1027  34020  python

# %%
python_tags_df['Id'].is_unique
# Out:
# True

# %%
python_tags_df.drop_duplicates("Id" , keep='first')
python_tags_df.shape
# Out:
# (64601, 2)

# %%
python_questions_df = pd.DataFrame()
chunksize = 10000
i = 0
for chunk in pd.read_csv('Dataset/Questions.csv', chunksize=chunksize, encoding="ISO-8859-1"):
    if i < 2:
        temp_questions_df = pd.merge(chunk, python_tags_df, on= 'Id', how='inner')
        python_questions_df = python_questions_df.append(temp_questions_df, ignore_index=True)
    else:
        continue
        
    i += 1
    
python_questions_df.shape
# Out:
# (788, 8)

# %%
python_questions_df.head()
# Out:
#       Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0  11060        912.0  2008-08-14T13:59:21Z        NaN     18
# 1  17250        394.0  2008-08-20T00:16:40Z        NaN     24
# 2  19030        745.0  2008-08-20T22:50:55Z        NaN      2
# 3  31340     242853.0  2008-08-27T23:44:47Z        NaN     71
# 4  34020       3561.0  2008-08-29T05:43:16Z        NaN     17
#
#                                                Title  \
# 0           How should I unit test a code-generator?
# 1             Create an encrypted ZIP file in Python
# 2  How to check set of files conform to a naming ...
# 3  How do threads work in Python, and what are co...
# 4                          Are Python threads buggy?
#
#                                                 Body     Tag
# 0  <p>This is a difficult and open-ended question...  python
# 1  <p>I'm creating an ZIP file with ZipFile in Py...  python
# 2  <p>I have a bunch of files (TV episodes, altho...  python
# 3  <p>I've been trying to wrap my head around how...  python
# 4  <p>A reliable coder friend told me that Python...  python

# %%
python_answers_df = pd.DataFrame()
chunksize = 10000
i = 0
for chunk in pd.read_csv('Dataset/Answers.csv', chunksize=chunksize, encoding="ISO-8859-1"):
    if i < 2:
        temp_questions_df = pd.merge(chunk, python_tags_df, how='inner', left_on=['ParentId'], right_on=['Id'])
        python_answers_df = python_answers_df.append(temp_questions_df, ignore_index=True)
    else:
        continue
    
    i += 1
    
python_answers_df.shape
# Out:
# (715, 8)

# %%
python_answers_df.head()
# Out:
#     Id_x  OwnerUserId          CreationDate  ParentId  Score  \
# 0  11074        267.0  2008-08-14T14:04:25Z     11060      8
# 1  11128        414.0  2008-08-14T14:38:19Z     11060      0
# 2  11235       1343.0  2008-08-14T15:46:01Z     11060      0
# 3  11443        825.0  2008-08-14T18:15:42Z     11060      4
# 4  70778      11521.0  2008-09-16T09:41:03Z     11060      0
#
#                                                 Body   Id_y     Tag
# 0  <p>I started writing up a summary of my experi...  11060  python
# 1  <p>Yes, results are the ONLY thing that matter...  11060  python
# 2  <p>If you are running on *nux you might consid...  11060  python
# 3  <p>Recall that "unit testing" is only one kind...  11060  python
# 4  <p>Just wanted to point out that you can still...  11060  python

# %%
python_questions_df.drop(['OwnerUserId', 'CreationDate', 'ClosedDate'],
                       axis=1, inplace=True)
python_questions_df.rename(columns={'Body': 'Q_Body', 'Score': 'Q_Score'}, inplace=True)
python_answers_df.drop(['Id_x', 'ParentId',  'CreationDate', 'OwnerUserId', 'Tag'], axis=1, inplace=True)
python_answers_df.rename(columns={'Id_y':'Id', 'Body': 'A_Body', 'Score': 'A_Score'}, inplace=True)

# %%
python_merged_df = pd.merge(python_questions_df, python_answers_df, on= 'Id', how='inner')
print(python_merged_df.shape)
python_merged_df.head()
# Out:
# (715, 7)
#       Id  Q_Score                                     Title  \
# 0  11060       18  How should I unit test a code-generator?
# 1  11060       18  How should I unit test a code-generator?
# 2  11060       18  How should I unit test a code-generator?
# 3  11060       18  How should I unit test a code-generator?
# 4  11060       18  How should I unit test a code-generator?
#
#                                               Q_Body     Tag  A_Score  \
# 0  <p>This is a difficult and open-ended question...  python        8
# 1  <p>This is a difficult and open-ended question...  python        0
# 2  <p>This is a difficult and open-ended question...  python        0
# 3  <p>This is a difficult and open-ended question...  python        4
# 4  <p>This is a difficult and open-ended question...  python        0
#
#                                               A_Body
# 0  <p>I started writing up a summary of my experi...
# 1  <p>Yes, results are the ONLY thing that matter...
# 2  <p>If you are running on *nux you might consid...
# 3  <p>Recall that "unit testing" is only one kind...
# 4  <p>Just wanted to point out that you can still...

# %%
python_merged_df.sort_values('Q_Score', ascending=False, inplace=True)
python_merged_df.head()
# Out:
#          Id  Q_Score                                              Title  \
# 613  306400      824  How do I randomly select an item from a list u...
# 274  152580      588  What's the canonical way to check for type in ...
# 273  152580      588  What's the canonical way to check for type in ...
# 272  152580      588  What's the canonical way to check for type in ...
# 271  152580      588  What's the canonical way to check for type in ...
#
#                                                 Q_Body     Tag  A_Score  \
# 613  <p>Assume I have the following list:</p>\n\n<p...  python     1462
# 274  <p>What is the best way to check whether a giv...  python      105
# 273  <p>What is the best way to check whether a giv...  python        4
# 272  <p>What is the best way to check whether a giv...  python      735
# 271  <p>What is the best way to check whether a giv...  python       22
#
#                                                 A_Body
# 613  <p>Use <a href="https://docs.python.org/2/libr...
# 274  <p>The <strong>most</strong> Pythonic way to c...
# 273  <p>I think the cool thing about using a dynami...
# 272  <p>To check if the type of <code>o</code> is e...
# 271  <p><code>isinstance(o, str)</code> will return...

# %%
python_merged_df.columns
# Out:
# Index(['Id', 'Q_Score', 'Title', 'Q_Body', 'Tag', 'A_Score', 'A_Body'], dtype='object')

# %%
python_merged_df = python_merged_df.reindex(['Id', 'A_Score', 'Q_Score', 'Tag', 'Title', 'Q_Body',
                                              'A_Body'], axis=1)
python_merged_df.head()
# Out:
#          Id  A_Score  Q_Score     Tag  \
# 613  306400     1462      824  python
# 274  152580      105      588  python
# 273  152580        4      588  python
# 272  152580      735      588  python
# 271  152580       22      588  python
#
#                                                  Title  \
# 613  How do I randomly select an item from a list u...
# 274  What's the canonical way to check for type in ...
# 273  What's the canonical way to check for type in ...
# 272  What's the canonical way to check for type in ...
# 271  What's the canonical way to check for type in ...
#
#                                                 Q_Body  \
# 613  <p>Assume I have the following list:</p>\n\n<p...
# 274  <p>What is the best way to check whether a giv...
# 273  <p>What is the best way to check whether a giv...
# 272  <p>What is the best way to check whether a giv...
# 271  <p>What is the best way to check whether a giv...
#
#                                                 A_Body
# 613  <p>Use <a href="https://docs.python.org/2/libr...
# 274  <p>The <strong>most</strong> Pythonic way to c...
# 273  <p>I think the cool thing about using a dynami...
# 272  <p>To check if the type of <code>o</code> is e...
# 271  <p><code>isinstance(o, str)</code> will return...

# %%
# python_merged_df.to_csv('Python_Questions.csv')

# %%
def convert_to_lower_remove_patterns(text):
    text = re.sub(r'@[\w]*', '', text)
    text = re.sub(r'<[^<]+?>', '', text) 
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    for word in text.split():
        if word.lower() in contractions:
            text = text.replace(word, contractions[word.lower()])
    text = text.lower()
    return text
 
# Removal of all characters except of small/ Capital words and numbers
def remove_other_character(text):
    handle_pattern = re.compile(r"[^a-zA-Z0-9 ]")
    return handle_pattern.sub(r'', text)
    
# Remove short words (length lesser equal to 3)    
def remove_small_words(text):
    return ' '.join([w for w in text.split() if len(w) > 3])

STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(STOPWORDS, text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# Removal/Converion of emojis
def remove_emoji(string):
    emoji_pattern = re.compile("["
                       u"\U0001F600-\U0001F64F"  # emoticons
                       u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                       u"\U0001F680-\U0001F6FF"  # transport & map symbols
                       u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                       u"\U00002702-\U000027B0"
                       u"\U000024C2-\U0001F251"
                       "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def convert_emojis(UNICODE_EMO, text):
    for emot in UNICODE_EMO:
        text = re.sub(r'('+emot+')', "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()), text)
    return text

# Removal of Emoticons
emoticon_pattern = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
def remove_emoticons(text):
    return emoticon_pattern.sub(r'', text)

# Conversion of emoticons to words
def convert_emoticons(EMOTICONS, text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text

# Removal of Frequent Words
def remove_frequent_words(FREQWORDS, text):
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

# Removal of Rare words
def remove_rare_words(RAREWORDS, text):
    return " ".join([word for word in str(text).split() if word not in RAREWORDS])

# Stemming
def stem_words(text):
    stemmer = PorterStemmer()
    return " ".join([stemmer.stem(word) for word in text.split()])

# Lemmatization
def lemmatize_words(text):
    lemmatizer = WordNetLemmatizer()
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

chat_words_map_dict = {}
chat_words_list = []
for line in chat_words_str.split("\n"):
    if line != "":
        cw = line.split("=")[0]
        cw_expanded = line.split("=")[1]
        chat_words_list.append(cw)
        chat_words_map_dict[cw] = cw_expanded
chat_words_list = set(chat_words_list)

def chat_words_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words_list:
            new_text.append(chat_words_map_dict[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

cnt = Counter()

# %%
python_merged_df['P_Title'] = python_merged_df['Title'].apply(lambda text: convert_to_lower_remove_patterns(text))
python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: remove_stopwords(STOPWORDS, text))
python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: convert_emojis(UNICODE_EMO, text))
python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: convert_emoticons(EMOTICONS, text))
python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: remove_other_character(text))
# python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: remove_small_words(text))
python_merged_df['P_Title'] = python_merged_df['P_Title'].apply(lambda text: stem_words(text))

for text in python_merged_df['P_Title'].values:
    for word in text.split():
        cnt[word] += 1
        
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-10:-1] ])

python_merged_df['P_Title_wo_freq'] = python_merged_df['P_Title'].apply(lambda text: 
                                                          remove_frequent_words(FREQWORDS, text))
python_merged_df['P_Title_wo_freq'] = python_merged_df['P_Title_wo_freq'].apply(lambda text: 
                                                                  remove_rare_words(RAREWORDS, text))

python_merged_df.head()
# Out:
#          Id  A_Score  Q_Score     Tag  \
# 613  306400     1462      824  python
# 274  152580      105      588  python
# 273  152580        4      588  python
# 272  152580      735      588  python
# 271  152580       22      588  python
#
#                                                  Title  \
# 613  How do I randomly select an item from a list u...
# 274  What's the canonical way to check for type in ...
# 273  What's the canonical way to check for type in ...
# 272  What's the canonical way to check for type in ...
# 271  What's the canonical way to check for type in ...
#
#                                                 Q_Body  \
# 613  <p>Assume I have the following list:</p>\n\n<p...
# 274  <p>What is the best way to check whether a giv...
# 273  <p>What is the best way to check whether a giv...
# 272  <p>What is the best way to check whether a giv...
# 271  <p>What is the best way to check whether a giv...
#
#                                                 A_Body  \
# 613  <p>Use <a href="https://docs.python.org/2/libr...
# 274  <p>The <strong>most</strong> Pythonic way to c...
# 273  <p>I think the cool thing about using a dynami...
# 272  <p>To check if the type of <code>o</code> is e...
# 271  <p><code>isinstance(o, str)</code> will return...
#
#                                   P_Title       P_Title_wo_freq
# 613  randomli select item list use python  randomli select item
# 274           canon way check type python      canon check type
# 273           canon way check type python      canon check type
# 272           canon way check type python      canon check type
# 271           canon way check type python      canon check type

# %%
python_merged_df['P_Q_Body'] = python_merged_df['Q_Body'].apply(lambda text: convert_to_lower_remove_patterns(text))
python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: remove_stopwords(STOPWORDS, text))
python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: convert_emojis(UNICODE_EMO, text))
python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: convert_emoticons(EMOTICONS, text))
python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: remove_other_character(text))
# python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: remove_small_words(text))
python_merged_df['P_Q_Body'] = python_merged_df['P_Q_Body'].apply(lambda text: stem_words(text))

for text in python_merged_df['P_Q_Body'].values:
    for word in text.split():
        cnt[word] += 1
        
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-10:-1] ])

python_merged_df['P_Q_Body_wo_freq'] = python_merged_df['P_Q_Body'].apply(lambda text: 
                                                          remove_frequent_words(FREQWORDS, text))
python_merged_df['P_Q_Body_wo_freq'] = python_merged_df['P_Q_Body_wo_freq'].apply(lambda text: 
                                                                  remove_rare_words(RAREWORDS, text))

# %%
python_merged_df['P_A_Body'] = python_merged_df['A_Body'].apply(lambda text: convert_to_lower_remove_patterns(text))
python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: remove_stopwords(STOPWORDS, text))
python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: convert_emojis(UNICODE_EMO, text))
python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: convert_emoticons(EMOTICONS, text))
python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: remove_other_character(text))
# python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: remove_small_words(text))
python_merged_df['P_A_Body'] = python_merged_df['P_A_Body'].apply(lambda text: stem_words(text))

for text in python_merged_df['P_A_Body'].values:
    for word in text.split():
        cnt[word] += 1
        
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-10:-1] ])

python_merged_df['P_A_Body_wo_freq'] = python_merged_df['P_A_Body'].apply(lambda text: 
                                                          remove_frequent_words(FREQWORDS, text))
python_merged_df['P_A_Body_wo_freq'] = python_merged_df['P_A_Body_wo_freq'].apply(lambda text: 
                                                                  remove_rare_words(RAREWORDS, text))

# %%
python_merged_df.drop(['P_Title', 'P_Q_Body', 'P_A_Body'], axis=1, inplace=True)
python_merged_df.head()
# Out:
#          Id  A_Score  Q_Score     Tag  \
# 613  306400     1462      824  python
# 274  152580      105      588  python
# 273  152580        4      588  python
# 272  152580      735      588  python
# 271  152580       22      588  python
#
#                                                  Title  \
# 613  How do I randomly select an item from a list u...
# 274  What's the canonical way to check for type in ...
# 273  What's the canonical way to check for type in ...
# 272  What's the canonical way to check for type in ...
# 271  What's the canonical way to check for type in ...
#
#                                                 Q_Body  \
# 613  <p>Assume I have the following list:</p>\n\n<p...
# 274  <p>What is the best way to check whether a giv...
# 273  <p>What is the best way to check whether a giv...
# 272  <p>What is the best way to check whether a giv...
# 271  <p>What is the best way to check whether a giv...
#
#                                                 A_Body       P_Title_wo_freq  \
# 613  <p>Use <a href="https://docs.python.org/2/libr...  randomli select item
# 274  <p>The <strong>most</strong> Pythonic way to c...      canon check type
# 273  <p>I think the cool thing about using a dynami...      canon check type
# 272  <p>To check if the type of <code>o</code> is e...      canon check type
# 271  <p><code>isinstance(o, str)</code> will return...      canon check type
#
#                                       P_Q_Body_wo_freq  \
# 613  assum follow list foo a b d e simplest retriev...
# 274  best check whether given object given type che...
# 273  best check whether given object given type che...
# 272  best check whether given object given type che...
# 271  best check whether given object given type che...
#
#                                       P_A_Body_wo_freq
# 613  randomchoic import random foo a b d e printran...
# 274  check type object is check it sinc encourag du...
# 273  think cool thing dynam realli check someth tha...
# 272  check type exactli str typeo str check instanc...
# 271  isinstanceo str return true str type inherit s...

# %% [markdown]
# #### Most used words using WordCloud

# %%
all_title_words = ' '.join([text for text in python_merged_df['P_Title_wo_freq']])
all_body_words = ' '.join([text for text in python_merged_df['P_Q_Body_wo_freq']])
all_combined_words = ' '.join([text for text in python_merged_df['P_A_Body_wo_freq']])

wordcloud_title = WordCloud(width=800, height=500, random_state=21, max_font_size=100).generate(all_title_words)
plt.rcParams['figure.figsize'] = (14, 8)
plt.imshow(wordcloud_title, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud_title = WordCloud(width=800, height=500, random_state=21, max_font_size=100).generate(all_body_words)
plt.rcParams['figure.figsize'] = (14, 8)
plt.imshow(wordcloud_title, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud_title = WordCloud(width=800, height=500, random_state=21, max_font_size=100).generate(all_combined_words)
plt.rcParams['figure.figsize'] = (14, 8)
plt.imshow(wordcloud_title, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
python_merged_df['ProcessedText'] = python_merged_df['P_Title_wo_freq'].str.cat(python_merged_df['P_Q_Body_wo_freq'],
                                                                                sep=" ")

# %%
python_merged_df.head()
# Out:
#          Id  A_Score  Q_Score     Tag  \
# 613  306400     1462      824  python
# 274  152580      105      588  python
# 273  152580        4      588  python
# 272  152580      735      588  python
# 271  152580       22      588  python
#
#                                                  Title  \
# 613  How do I randomly select an item from a list u...
# 274  What's the canonical way to check for type in ...
# 273  What's the canonical way to check for type in ...
# 272  What's the canonical way to check for type in ...
# 271  What's the canonical way to check for type in ...
#
#                                                 Q_Body  \
# 613  <p>Assume I have the following list:</p>\n\n<p...
# 274  <p>What is the best way to check whether a giv...
# 273  <p>What is the best way to check whether a giv...
# 272  <p>What is the best way to check whether a giv...
# 271  <p>What is the best way to check whether a giv...
#
#                                                 A_Body       P_Title_wo_freq  \
# 613  <p>Use <a href="https://docs.python.org/2/libr...  randomli select item
# 274  <p>The <strong>most</strong> Pythonic way to c...      canon check type
# 273  <p>I think the cool thing about using a dynami...      canon check type
# 272  <p>To check if the type of <code>o</code> is e...      canon check type
# 271  <p><code>isinstance(o, str)</code> will return...      canon check type
#
#                                       P_Q_Body_wo_freq  \
# 613  assum follow list foo a b d e simplest retriev...
# 274  best check whether given object given type che...
# 273  best check whether given object given type che...
# 272  best check whether given object given type che...
# 271  best check whether given object given type che...
#
#                                       P_A_Body_wo_freq  \
# 613  randomchoic import random foo a b d e printran...
# 274  check type object is check it sinc encourag du...
# 273  think cool thing dynam realli check someth tha...
# 272  check type exactli str typeo str check instanc...
# 271  isinstanceo str return true str type inherit s...
#
#                                          ProcessedText
# 613  randomli select item assum follow list foo a b...
# 274  canon check type best check whether given obje...
# 273  canon check type best check whether given obje...
# 272  canon check type best check whether given obje...
# 271  canon check type best check whether given obje...

# %%
# python_merged_df.to_csv('Python_Cleaned_Questions.csv')

# %% [markdown]
# ## Vectorize the words with best 1000 features for Bag-Of-Words model, TFiDF model and Word2Vec model

# %%
tf_idf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=2, max_features=1000, stop_words='english')
# tfidf_qstn = tf_idf_vectorizer.fit_transform(python_merged_df['ProcessedText'])
tfidf_answer = tf_idf_vectorizer.fit_transform(python_merged_df['P_A_Body_wo_freq'])
tfidf_answer.shape
# Out:
# (715, 1000)

# %%
tokenize_text = python_merged_df['ProcessedText'].apply(lambda x: x.split())
model_w2v = gensim.models.Word2Vec(tokenize_text, size=200, window=5, 
                                   min_count=2, sg=1, hs=0, negative=10, workers=2, seed=34)
model_w2v.train(tokenize_text, total_examples=len(python_merged_df['ProcessedText']), epochs=20)
# Out:
# (658335, 701660)

# %%
tokenize_answer_text = python_merged_df['P_A_Body_wo_freq'].apply(lambda x: x.split())
model_answer_w2v = gensim.models.Word2Vec(tokenize_text, size=200, window=5, 
                                   min_count=2, sg=1, hs=0, negative=10, workers=2, seed=34)
model_answer_w2v.train(tokenize_answer_text, total_examples=len(python_merged_df['P_A_Body_wo_freq']), epochs=20)
# Out:
# (439784, 612900)

# %%
def word_vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count=0
    
    for word in tokens:
        try:
            vec += model_w2v[word].reshape((1, size))
            count += 1
        except KeyError:
            continue
            
    if count != 0:
        vec /= count
        
    return vec

# %%
wordvec_arrays = np.zeros((len(tokenize_text), 200))
for i in range(len(tokenize_text)):
    wordvec_arrays[i,:] = word_vector(tokenize_text[i], 200)
    wordvec_q_df = pd.DataFrame(wordvec_arrays)

wordvec_q_df.shape
# Out:
# (715, 200)

# %%
wordvec_answer_arrays = np.zeros((len(tokenize_answer_text), 200))
for i in range(len(tokenize_text)):
    wordvec_answer_arrays[i,:] = word_vector(tokenize_answer_text[i], 200)
    wordvec_answer_df = pd.DataFrame(wordvec_answer_arrays)

wordvec_answer_df.shape
# Out:
# (715, 200)

# %%
model_answer_w2v.wv.save_word2vec_format('model_answer_w2v.bin', binary=True)

# %%
wordvec_answer_df[0:1]
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.089236 -0.080797  0.075783  0.092526  0.033612  0.115486 -0.065789
#
#         7         8         9    ...       190       191       192       193  \
# 0 -0.441763  0.101261  0.237039  ... -0.392814 -0.175259  0.157007 -0.276542
#
#         194       195       196       197       198       199
# 0 -0.069368 -0.184972  0.046689  0.074295  0.059345  0.143726
#
# [1 rows x 200 columns]

# %% [markdown]
# ### Finding similarity among the sentences

# %% [markdown]
# https://datascience.stackexchange.com/questions/23969/sentence-similarity-prediction

# %%
python_merged_df[python_merged_df.Id == 152580]
# Out:
#          Id  A_Score  Q_Score     Tag  \
# 274  152580      105      588  python
# 273  152580        4      588  python
# 272  152580      735      588  python
# 271  152580       22      588  python
# 270  152580       11      588  python
#
#                                                  Title  \
# 274  What's the canonical way to check for type in ...
# 273  What's the canonical way to check for type in ...
# 272  What's the canonical way to check for type in ...
# 271  What's the canonical way to check for type in ...
# 270  What's the canonical way to check for type in ...
#
#                                                 Q_Body  \
# 274  <p>What is the best way to check whether a giv...
# 273  <p>What is the best way to check whether a giv...
# 272  <p>What is the best way to check whether a giv...
# 271  <p>What is the best way to check whether a giv...
# 270  <p>What is the best way to check whether a giv...
#
#                                                 A_Body   P_Title_wo_freq  \
# 274  <p>The <strong>most</strong> Pythonic way to c...  canon check type
# 273  <p>I think the cool thing about using a dynami...  canon check type
# 272  <p>To check if the type of <code>o</code> is e...  canon check type
# 271  <p><code>isinstance(o, str)</code> will return...  canon check type
# 270  <pre><code>isinstance(o, str)\n</code></pre>\n...  canon check type
#
#                                       P_Q_Body_wo_freq  \
# 274  best check whether given object given type che...
# 273  best check whether given object given type che...
# 272  best check whether given object given type che...
# 271  best check whether given object given type che...
# 270  best check whether given object given type che...
#
#                                       P_A_Body_wo_freq  \
# 274  check type object is check it sinc encourag du...
# 273  think cool thing dynam realli check someth tha...
# 272  check type exactli str typeo str check instanc...
# 271  isinstanceo str return true str type inherit s...
# 270                               isinstanceo str link
#
#                                          ProcessedText
# 274  canon check type best check whether given obje...
# 273  canon check type best check whether given obje...
# 272  canon check type best check whether given obje...
# 271  canon check type best check whether given obje...
# 270  canon check type best check whether given obje...

# %%
python_merged_df[python_merged_df.Id == 152580].Title[0:1]
# Out:
# 274    What's the canonical way to check for type in ...
# Name: Title, dtype: object

# %%
answers_152580 = python_merged_df[python_merged_df.Id == 152580][['A_Score', 'P_A_Body_wo_freq']]
answers_152580.sort_values(by='A_Score')
# Out:
#      A_Score                                   P_A_Body_wo_freq
# 273        4  think cool thing dynam realli check someth tha...
# 270       11                               isinstanceo str link
# 271       22  isinstanceo str return true str type inherit s...
# 274      105  check type object is check it sinc encourag du...
# 272      735  check type exactli str typeo str check instanc...

# %%
user_input = 'think cool thing dynam languag realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object'

# %%
ans = answers_152580['P_A_Body_wo_freq'].tolist() 
ans.append(user_input)
ans
# Out:
# ['check type object is check it sinc encourag duck type tri object method them look writabl object check subclass tri write method cours sometim nice abstract break isinstanceobj cl need sparingli',
#  'think cool thing dynam realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object test alot get data web urllib2urlopen return object turn pass almost method read implement read method real sure time place isinst otherwis probabl happyfaceorsmiley',
#  'check type exactli str typeo str check instanc str subclass str thi canon isinstanceo str follow also work case issubclasstypeo str typeo str strsubclass see builtin librari refer relev inform one note case may actual isinstanceo basestr also catch unicod string unicod subclass str str unicod subclass basestr altern isinst accept tupl class return true x instanc subclass str unicod isinstanceo str unicod',
#  'isinstanceo str return true str type inherit str typeo str return true str return fals type inherit str',
#  'isinstanceo str link',
#  'think cool thing dynam languag realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object']

# %%
tf_idf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=2, max_features=1000, stop_words='english')
tfs = tf_idf_vectorizer.fit_transform(ans)

# %%
pairwise_similarity = tfs * tfs.T

# %%
arr = pairwise_similarity.toarray()
np.fill_diagonal(arr, np.nan)

# %%
arr
# Out:
# array([[       nan, 0.58002638, 0.18605746, 0.10592392, 0.        ,
#         0.49853199],
#        [0.58002638,        nan, 0.04928088, 0.05190836, 0.        ,
#         0.94664211],
#        [0.18605746, 0.04928088,        nan, 0.81636293, 0.76650063,
#         0.03134688],
#        [0.10592392, 0.05190836, 0.81636293,        nan, 0.65552559,
#         0.        ],
#        [0.        , 0.        , 0.76650063, 0.65552559,        nan,
#         0.        ],
#        [0.49853199, 0.94664211, 0.03134688, 0.        , 0.        ,
#                nan]])

# %% [markdown]
# #### Word2vec

# %%
filepath = "model_answer_w2v.bin"

from gensim.models import KeyedVectors


wv_from_bin = KeyedVectors.load_word2vec_format(filepath, binary=True) 
#extracting words7 vectors from google news vector
embeddings_index = {}
for word, vector in zip(wv_from_bin.vocab, wv_from_bin.vectors):
    coefs = np.asarray(vector, dtype='float32')
    embeddings_index[word] = coefs

# %%
def avg_feature_vector(sentence, model, num_features):
    words = sentence.split()
    #feature vector is initialized as an empty array
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_words = 0
    for word in words:
        if word in embeddings_index.keys():
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %%
from scipy.spatial import distance

# %%
answersList = answers_152580['P_A_Body_wo_freq'].tolist() 
answersList
# Out:
# ['check type object is check it sinc encourag duck type tri object method them look writabl object check subclass tri write method cours sometim nice abstract break isinstanceobj cl need sparingli',
#  'think cool thing dynam realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object test alot get data web urllib2urlopen return object turn pass almost method read implement read method real sure time place isinst otherwis probabl happyfaceorsmiley',
#  'check type exactli str typeo str check instanc str subclass str thi canon isinstanceo str follow also work case issubclasstypeo str typeo str strsubclass see builtin librari refer relev inform one note case may actual isinstanceo basestr also catch unicod string unicod subclass str str unicod subclass basestr altern isinst accept tupl class return true x instanc subclass str unicod isinstanceo str unicod',
#  'isinstanceo str return true str type inherit str typeo str return true str return fals type inherit str',
#  'isinstanceo str link']

# %%
s1_afv = avg_feature_vector(user_input, model= embeddings_index, num_features=200 )

for answer in answersList:
    s2_afv = avg_feature_vector(answer,model= embeddings_index, num_features=200)
    cos = distance.cosine(s1_afv, s2_afv)
    print(cos)
# Out:
# 0.05922156572341919
# 0.0177614688873291
# 0.17949312925338745
# 0.29538440704345703
# 0.26252269744873047

# %% [markdown]
# #### Doc2Vec

# %%
from gensim.models.doc2vec import LabeledSentence
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from tqdm import tqdm

# %%
def add_label(ans):
    output = []
    for i, s in zip(ans.index, ans):
        output.append(LabeledSentence(s, ["answer_" + str(i)]))
        
    return output

# %%
labeled_answers = add_label(tokenize_answer_text)

# %%
labeled_answers[0:6]
# Out:
# [LabeledSentence(words=['randomchoic', 'import', 'random', 'foo', 'a', 'b', 'd', 'e', 'printrandomchoicefoo'], tags=['answer_613']),
#  LabeledSentence(words=['check', 'type', 'object', 'is', 'check', 'it', 'sinc', 'encourag', 'duck', 'type', 'tri', 'object', 'method', 'them', 'look', 'writabl', 'object', 'check', 'subclass', 'tri', 'write', 'method', 'cours', 'sometim', 'nice', 'abstract', 'break', 'isinstanceobj', 'cl', 'need', 'sparingli'], tags=['answer_274']),
#  LabeledSentence(words=['think', 'cool', 'thing', 'dynam', 'realli', 'check', 'someth', 'that', 'call', 'requir', 'method', 'object', 'catch', 'attributeerror', 'later', 'allow', 'call', 'method', 'seemingli', 'unrel', 'object', 'accomplish', 'differ', 'task', 'mock', 'object', 'test', 'alot', 'get', 'data', 'web', 'urllib2urlopen', 'return', 'object', 'turn', 'pass', 'almost', 'method', 'read', 'implement', 'read', 'method', 'real', 'sure', 'time', 'place', 'isinst', 'otherwis', 'probabl', 'happyfaceorsmiley'], tags=['answer_273']),
#  LabeledSentence(words=['check', 'type', 'exactli', 'str', 'typeo', 'str', 'check', 'instanc', 'str', 'subclass', 'str', 'thi', 'canon', 'isinstanceo', 'str', 'follow', 'also', 'work', 'case', 'issubclasstypeo', 'str', 'typeo', 'str', 'strsubclass', 'see', 'builtin', 'librari', 'refer', 'relev', 'inform', 'one', 'note', 'case', 'may', 'actual', 'isinstanceo', 'basestr', 'also', 'catch', 'unicod', 'string', 'unicod', 'subclass', 'str', 'str', 'unicod', 'subclass', 'basestr', 'altern', 'isinst', 'accept', 'tupl', 'class', 'return', 'true', 'x', 'instanc', 'subclass', 'str', 'unicod', 'isinstanceo', 'str', 'unicod'], tags=['answer_272']),
#  LabeledSentence(words=['isinstanceo', 'str', 'return', 'true', 'str', 'type', 'inherit', 'str', 'typeo', 'str', 'return', 'true', 'str', 'return', 'fals', 'type', 'inherit', 'str'], tags=['answer_271']),
#  LabeledSentence(words=['isinstanceo', 'str', 'link'], tags=['answer_270'])]

# %%
model_d2v = Doc2Vec(dm=1,
                  dm_mean=1,
                  size=200,
                  window=5,
                  negative=7,
                  min_count=3,
                  workers=3,
                  alpha=0.01,
                  seed=23)

# %%
model_d2v.build_vocab(labeled_answers)

# %%
# Train the model with 20 epochs

for epoch in range(20):
    model_d2v.train(labeled_answers,epochs=model_d2v.iter,total_examples=model_d2v.corpus_count)
    print("Epoch #{} is complete.".format(epoch+1))
# Out:
# Epoch #1 is complete.
# Epoch #2 is complete.
# Epoch #3 is complete.
# Epoch #4 is complete.
# Epoch #5 is complete.
# Epoch #6 is complete.
# Epoch #7 is complete.
# Epoch #8 is complete.
# Epoch #9 is complete.
# Epoch #10 is complete.
# Epoch #11 is complete.
# Epoch #12 is complete.
# Epoch #13 is complete.
# Epoch #14 is complete.
# Epoch #15 is complete.
# Epoch #16 is complete.
# Epoch #17 is complete.
# Epoch #18 is complete.
# Epoch #19 is complete.
# Epoch #20 is complete.

# %%
model_d2v.most_similar('random')
# Out:
# [('tb', 0.9180579781532288),
#  ('gtgtgt', 0.9139472842216492),
#  ('urlpars', 0.9075108170509338),
#  ('itertool', 0.9071712493896484),
#  ('detect', 0.9043265581130981),
#  ('http404', 0.9001170992851257),
#  ('usersdspitz', 0.8967869281768799),
#  ('eventlistviewspy4', 0.89673912525177),
#  ('curli', 0.8816729187965393),
#  ('d1', 0.8806095719337463)]

# %%
model_d2v.save("model_answer_d2v.model")

# %%
model= Doc2Vec.load("model_answer_d2v.model")

# %%
for answer in answersList: 
    vec1 = model.infer_vector(user_input.split())
    vec2 = model.infer_vector(answer.split())

    cos_distance = distance.cosine(vec1, vec2)
    print(cos_distance)
# Out:
# 0.20871257781982422
# 0.09335511922836304
# 0.36695075035095215
# 0.4350174069404602
# 1.0214545279741287

# %% [markdown]
# #### GLoVE using spacy

# %%
# conda install -c conda-forge spacy-model-en_core_web_lg

# %%
nlp = spacy.load('en_core_web_lg')

# %%
for answer in answersList:
    doc1 = nlp(answer)
    doc2 = nlp(user_input)
    print("spaCy :", doc1.similarity(doc2))

    print(np.dot(doc1.vector, doc2.vector) / (np.linalg.norm(doc1.vector) * np.linalg.norm(doc2.vector)))
# Out:
# spaCy : 0.9015951915220441
# 0.90159523
# spaCy : 0.9736185311629513
# 0.97361857
# spaCy : 0.6575672839881355
# 0.6575673
# spaCy : 0.5009877907059969
# 0.5009878
# spaCy : 0.3739809089116808
# 0.3739809

# %% [markdown]
# #### Using Keras LSTM Manhattaan Distance measurement

# %%
# https://medium.com/@gautam.karmakar/manhattan-lstm-model-for-text-similarity-2351f80d72f1
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Add
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### SentenceBERT and Transformers

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
# conda install -c huggingface transformers
# conda install -c conda-forge sentence-transformers
# conda install pytorch torchvision torchaudio -c pytorch

from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sentence_embeddings = sbert_model.encode(answersList, show_progress_bar=False)
query_vec = sbert_model.encode([user_input], show_progress_bar=False)[0]

for sent in answersList:
    sim = cosine(query_vec, sbert_model.encode([sent], show_progress_bar=False)[0])
    print("Sentence = ", sent, "; similarity = ", sim, '\n')
# Out:
# Sentence =  check type object is check it sinc encourag duck type tri object method them look writabl object check subclass tri write method cours sometim nice abstract break isinstanceobj cl need sparingli ; similarity =  0.76449865
#
# Sentence =  think cool thing dynam realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object test alot get data web urllib2urlopen return object turn pass almost method read implement read method real sure time place isinst otherwis probabl happyfaceorsmiley ; similarity =  0.9422359
#
# Sentence =  check type exactli str typeo str check instanc str subclass str thi canon isinstanceo str follow also work case issubclasstypeo str typeo str strsubclass see builtin librari refer relev inform one note case may actual isinstanceo basestr also catch unicod string unicod subclass str str unicod subclass basestr altern isinst accept tupl class return true x instanc subclass str unicod isinstanceo str unicod ; similarity =  0.79397815
#
# Sentence =  isinstanceo str return true str type inherit str typeo str return true str return fals type inherit str ; similarity =  0.70185226
#
# Sentence =  isinstanceo str link ; similarity =  0.5343679

# %% [markdown]
# #### Universal Sentence Encoder (Deep Averaging Network)

# %%
import tensorflow_hub as hub
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
model = hub.load(module_url)
print ("module %s loaded" % module_url)
# Out:
# INFO:absl:Using /var/folders/_9/6qw6nfq936n3bl973r5qnzx80000gn/T/tfhub_modules to cache modules.
# INFO:absl:Downloading TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/4'.
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 80.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 130.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 230.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 280.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 380.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 460.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 590.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 650.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 770.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 860.00MB
# INFO:absl:Downloading https://tfhub.dev/google/universal-sentence-encoder/4: 940.00MB
# INFO:absl:Downloaded https://tfhub.dev/google/universal-sentence-encoder/4, Total size: 987.47MB
# INFO:absl:Downloaded TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/4'.
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
sentence_embeddings = model(answersList)
query = user_input
query_vec = model([query])[0]

# %%
for sent in answersList:
    sim = cosine(query_vec, model([sent])[0])
    print("Sentence = ", sent, "; similarity = ", sim, '\n')
# Out:
# Sentence =  check type object is check it sinc encourag duck type tri object method them look writabl object check subclass tri write method cours sometim nice abstract break isinstanceobj cl need sparingli ; similarity =  0.6063096
#
# Sentence =  think cool thing dynam realli check someth that call requir method object catch attributeerror later allow call method seemingli unrel object accomplish differ task mock object test alot get data web urllib2urlopen return object turn pass almost method read implement read method real sure time place isinst otherwis probabl happyfaceorsmiley ; similarity =  0.8822167
#
# Sentence =  check type exactli str typeo str check instanc str subclass str thi canon isinstanceo str follow also work case issubclasstypeo str typeo str strsubclass see builtin librari refer relev inform one note case may actual isinstanceo basestr also catch unicod string unicod subclass str str unicod subclass basestr altern isinst accept tupl class return true x instanc subclass str unicod isinstanceo str unicod ; similarity =  0.35041484
#
# Sentence =  isinstanceo str return true str type inherit str typeo str return true str return fals type inherit str ; similarity =  0.2735503
#
# Sentence =  isinstanceo str link ; similarity =  0.18118207
